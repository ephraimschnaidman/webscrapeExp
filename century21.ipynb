# %%
import requests
from bs4 import BeautifulSoup

r=requests.get("http://pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div", {"class": "propertyRow"})

all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")

page_no=soup.find_all("a",{"class":"Page"})[-1].text
print(page_no)
# Out:
# 3

# %%
l=[]
base_url="http://pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,int(page_no)*10,10):
    print(base_url+str(page)+".html")
    r=requests.get(base_url+str(page)+".html")
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div", {"class": "propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class","propAddressCollapse"})[0].text
        try:
            d["Locality"]=item.find_all("span",{"class","propAddressCollapse"})[1].text
        except:
            d["Locality"]=None
        d["Price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
        try:
            d["Beds"]=item.find("span",{"class","infoBed"}).text
        except:
            d["Beds"]=None

        try:
            d["Area"]=item.find("span",{"class","infoSqFt"}).text
        except:
            d["Area"]=None

        try:
            d["Full Baths"]=item.find("span",{"class","infoValueFullBath"}).text
        except:
            d["Full Baths"]=None

        try:
            d["Half Baths"]=item.find("span",{"class","infoValueHalfBath"}).text
        except:
            d["Half Baths"]=None

        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text

        l.append(d)
# Out:
# http://pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# http://pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# http://pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html

# %%
len(l)
# Out:
# 37

# %%
import pandas
df=pandas.DataFrame(l)
df
# Out:
#                           Address          Area    Beds    Full Baths  \
# 0                       0 Gateway          None    None          None
# 1           1003 Winchester Blvd.          None  4 Beds  4 Full Baths
# 2                   600 Talladega  3,154 Sq. Ft  5 Beds  3 Full Baths
# 3              3239 Spearhead Way  3,076 Sq. Ft  4 Beds  3 Full Baths
# 4              522 Emerald Street  1,172 Sq. Ft  3 Beds  3 Full Baths
# 5            1302 Veteran's Drive  1,932 Sq. Ft  4 Beds  2 Full Baths
# 6                1021 Cypress Cir  1,676 Sq. Ft  4 Beds  3 Full Baths
# 7                  913 Madison Dr  1,344 Sq. Ft  3 Beds  2 Full Baths
# 8               1344 Teton Street  1,920 Sq. Ft  3 Beds  2 Full Baths
# 9                  4 Minnies Lane  1,664 Sq. Ft  3 Beds  2 Full Baths
# 10                  9339 Sd 26900  2,560 Sq. Ft    None          None
# 11               RR674P13 Hwy 377  2,000 Sq. Ft    None          None
# 12                       0 Hwy 41          None    None          None
# 13                  9339 Sd 26900  2,560 Sq. Ft    None          None
# 14                  CR450 Hwy 377          None    None          None
# 15                  Cr 240 Cr 240  1,398 Sq. Ft    None          None
# 16                  RR674 Hwy 377  1,738 Sq. Ft    None          None
# 17                 9770a Sd 26900  1,080 Sq. Ft    None          None
# 18                  Lot17 CR 2630          None    None          None
# 19                 Tr12,16 CR 520          None    None          None
# 20   32575 S Shadow Mountain Road  2,318 Sq. Ft  3 Beds  2 Full Baths
# 21        32750 S Shangrila Drive  2,120 Sq. Ft  3 Beds  2 Full Baths
# 22      0000 Black Canyon Highway          None    None          None
# 23           34775 S CHOLLA Drive  1,220 Sq. Ft  3 Beds  2 Full Baths
# 24      33403 S. HA-WA-SI TERRACE  2,000 Sq. Ft  4 Beds  2 Full Baths
# 25          34263 S Bertha Street  2,260 Sq. Ft  5 Beds  2 Full Baths
# 26            33160 S Canyon Road  1,248 Sq. Ft  3 Beds  2 Full Baths
# 27        19421 E Todd Evans Road  1,404 Sq. Ft  3 Beds  2 Full Baths
# 28             18688 E AGUA Vista          None    None          None
# 29  50600 N Old Black Canyon Road          None    None          None
# 30      20101 E SQUAW VALLEY Road          None    None          None
# 31            33259 S Canyon Road  1,056 Sq. Ft  3 Beds   1 Full Bath
# 32          34558 S ROADRUNNER RD    784 Sq. Ft  2 Beds   1 Full Bath
# 33       19260 E Scenic Loop Road          None    None          None
# 34           19000 E MAREN Avenue          None    None          None
# 35          19350 E SAGUARO Drive          None    None          None
# 36         20650 E Amethyst Place          None    None          None
#
#      Half Baths                     Locality          Lot Size       Price
# 0          None       Rock Springs, WY 82901               NaN    $725,000
# 1          None       Rock Springs, WY 82901        0.21 Acres    $452,900
# 2          None       Rock Springs, WY 82901               NaN    $396,900
# 3   1 Half Bath       Rock Springs, WY 82901  Under 1/2 Acre,     $389,900
# 4          None       Rock Springs, WY 82901  Under 1/2 Acre,     $254,000
# 5          None       Rock Springs, WY 82901        0.27 Acres    $252,900
# 6          None       Rock Springs, WY 82901  Under 1/2 Acre,     $210,000
# 7          None       Rock Springs, WY 82901  Under 1/2 Acre,     $209,000
# 8          None       Rock Springs, WY 82901  Under 1/2 Acre,     $199,900
# 9          None       Rock Springs, WY 82901        2.02 Acres    $196,900
# 10         None        Rocksprings, TX 78880               NaN  $1,700,000
# 11         None        Rocksprings, TX 78880               NaN  $1,100,000
# 12         None        Rocksprings, TX 78880               NaN  $1,080,000
# 13         None        Rocksprings, TX 78880               NaN    $908,350
# 14         None        Rocksprings, TX 78880               NaN    $905,000
# 15         None        Rocksprings, TX 78880               NaN    $695,000
# 16         None        Rocksprings, TX 78880               NaN    $605,000
# 17         None        Rocksprings, TX 78880               NaN    $559,805
# 18         None        Rocksprings, TX 78880               NaN    $504,000
# 19         None        Rocksprings, TX 78880               NaN    $410,000
# 20         None  Black Canyon City, AZ 85324               NaN    $299,900
# 21         None  Black Canyon City, AZ 85324               NaN    $167,500
# 22         None  Black Canyon City, AZ 85324           5 Acres    $150,000
# 23         None  Black Canyon City, AZ 85324               NaN    $129,500
# 24         None  BLACK CANYON CITY, AZ 85324               NaN    $129,000
# 25         None  Black Canyon City, AZ 85324               NaN     $80,000
# 26         None  Black Canyon City, AZ 85324               NaN     $77,900
# 27         None  Black Canyon City, AZ 85324               NaN     $70,500
# 28         None  Black Canyon City, AZ 85324         0.7 Acres     $70,000
# 29         None  Black Canyon City, AZ 85324           3 Acres     $67,500
# 30         None  Black Canyon City, AZ 85324               NaN     $54,900
# 31         None  Black Canyon City, AZ 85324               NaN     $45,600
# 32         None  Black Canyon City, AZ 85324    Under 1/2 Acre     $40,000
# 33         None  Black Canyon City, AZ 85324        2.35 Acres     $30,000
# 34         None  Black Canyon City, AZ 85324        2.05 Acres     $29,000
# 35         None  Black Canyon City, AZ 85324        0.73 Acres     $28,995
# 36         None  Black Canyon City, AZ 85324        0.31 Acres     $15,000

# %%
df.to_csv("output.csv")
